# %% [markdown]
# <a href="https://colab.research.google.com/github/Soumyadantre/Internship_project-IIT-BHU-/blob/main/365Days_study.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('/content/data365overnt.csv')
print(df.shape[0])

#print(df.shape[0])
#removing null values
df = df.dropna()
print(df.shape[0])
# Out:
# <ipython-input-35-aa3892954dad>:4: DtypeWarning: Columns (4,7,9,10,12,13,14,25,40) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/content/data365overnt.csv')
# 157326
# 157326

# %%
df.columns
# Out:
# Index(['HHID', 'b51q1', 'b51q2', 'b51q3', 'b51q4', 'b51q5', 'b51q6', 'b51q7',
#        'b51q8', 'b51q9', 'b51q11', 'b51q12', 'b51q13', 'b51q14', 'b51q15',
#        'INDID', 'b4q1', 'b4q4', 'b4q5', 'b4q6', 'b4q7', 'b4q8', 'HHType',
#        'b3q5', 'b3q6', 'b3q7', 'TripID', 'b61q1', 'b61q2', 'b61q40', 'b61q50',
#        'b61q60', 'b61q700', 'b61q851', 'b61q852', 'b61q853', 'b61q850',
#        'b61q80', 'b61q10', 'b61q11', 'b61q12'],
#       dtype='object')

# %%
#renaming the coloumns
df.rename(columns={'b4q4': 'Gender', 'b4q5': 'Age',
                   'b4q6':'Marital status', 'b51q5': 'Purpose of the trip'
                   ,'b51q7' :'Mode of travel','b51q9':'Type of Stay',
                   'b51q14':'Main destination' },inplace=True)

# %%
df['Gender'] = df['Gender'].map({1: 'Male', 2:'Female',3 : 'third gender'})

df['Marital status'] = df['Marital status'].map({1: 'never married', 2:'currently married',3 : 'widowed', 4 : 'divorced'})
df['Type of Stay'] = df['Type of Stay'].map({'1': 'Type of Stay_hotel', "3":'Type of Stay_dharmashala',
                                             5 : 'Type of Stay_friends/relatives','4':'Type of Stay_RentedHouse','2':'Type of Stay_guestHouse', 9:'Type of Stay_others','9':'Type of Stay_others'})
df['Mode of travel'] = df['Mode of travel'].map({2: 'Mode of travel_bus', 3:'Mode of travel_train',6 : 'Mode of travel_own',
                                                 8: 'Mode of travel_motorizedVehicle',10: 'Mode of travel_Non_motorizedVehicle',"1":'Mode of travel_onFoot',4:'Mode of travel_ship/boat',5:'Mode of travel_air',"7":'Mode of travel_ownNonMotorized',"19":'Mode of travel_others'})
df['Purpose of the trip'] = df['Purpose of the trip'].map({2: 'Purpose of the trip_holidaying', 6:'Purpose of the trip_health/medical',7 : 'Purpose of the trip_shopping',1: 'Purpose of the trip_business',3: 'Purpose of the trip_social',4: 'Purpose of the trip_pilgrimage&religious',5: 'Purpose of the trip_education/training',9: 'Purpose of the trip_others'})
df['Main destination'] = df['Main destination'].map({'1': 'destination within the district', '2':'destination outside the district but within the state','3' : 'destination outside the district but within the state','4':	"final part of departure in Indian Territory for International trip"})

# %%
df
# Out:
#              HHID  b51q1  b51q2  b51q3 b51q4  \
# 0       744471101      1      1      1    46
# 1       744471102      1      1      1    25
# 2       744471201      1      1      1    43
# 3       744472101      1      2      1    65
# 4       744472101      1      2      2    55
# ...           ...    ...    ...    ...   ...
# 157321  924591202      1      2      1    40
# 157322  924591202      1      2      4     7
# 157323  924591202      2      3      1    40
# 157324  924591202      2      3      2    34
# 157325  924591202      2      3      4     7
#
#                        Purpose of the trip  b51q6            Mode of travel  \
# 0       Purpose of the trip_health/medical      2        Mode of travel_bus
# 1       Purpose of the trip_health/medical      2        Mode of travel_bus
# 2       Purpose of the trip_health/medical      2        Mode of travel_bus
# 3       Purpose of the trip_health/medical      2        Mode of travel_bus
# ...

# %% [markdown]
# **DATA ANALYSIS**

# %%
import numpy as np
from google.colab import autoviz

def categorical_histogram(df, colname, figscale=1, mpl_palette_name='Dark2'):
  from matplotlib import pyplot as plt
  import seaborn as sns
  df.groupby(colname).size().plot(kind='barh', color=sns.palettes.mpl_palette(mpl_palette_name), figsize=(8*figscale, 4.8*figscale))
  plt.gca().spines[['top', 'right',]].set_visible(False)
  return autoviz.MplChart.from_current_mpl_state()

chart = categorical_histogram(df, *['Gender'], **{})
chart
# Out:
# <img src="...">
#         <script></script>

# %%
import numpy as np
from google.colab import autoviz

def categorical_histogram(df, colname, figscale=1, mpl_palette_name='Dark2'):
  from matplotlib import pyplot as plt
  import seaborn as sns
  df.groupby(colname).size().plot(kind='barh', color=sns.palettes.mpl_palette(mpl_palette_name), figsize=(8*figscale, 4.8*figscale))
  plt.gca().spines[['top', 'right',]].set_visible(False)
  return autoviz.MplChart.from_current_mpl_state()

chart = categorical_histogram(df, *['Type of Stay'], **{})
chart
# Out:
# <img src="...

# %%
import numpy as np
from google.colab import autoviz

def categorical_histogram(df, colname, figscale=1, mpl_palette_name='Dark2'):
  from matplotlib import pyplot as plt
  import seaborn as sns
  df.groupby(colname).size().plot(kind='barh', color=sns.palettes.mpl_palette(mpl_palette_name), figsize=(8*figscale, 4.8*figscale))
  plt.gca().spines[['top', 'right',]].set_visible(False)
  return autoviz.MplChart.from_current_mpl_state()

chart = categorical_histogram(df, *['Main destination'], **{})
chart
# Out:
# <img src="...">
#         <script></script>

# %%
import numpy as np
from google.colab import autoviz

def categorical_histogram(df, colname, figscale=1, mpl_palette_name='Dark2'):
  from matplotlib import pyplot as plt
  import seaborn as sns
  df.groupby(colname).size().plot(kind='barh', color=sns.palettes.mpl_palette(mpl_palette_name), figsize=(8*figscale, 4.8*figscale))
  plt.gca().spines[['top', 'right',]].set_visible(False)
  return autoviz.MplChart.from_current_mpl_state()

chart = categorical_histogram(df, *['Mode of travel'], **{})
chart
# Out:
# <img src="...

# %%
import numpy as np
from google.colab import autoviz

def categorical_histogram(df, colname, figscale=1, mpl_palette_name='Dark2'):
  from matplotlib import pyplot as plt
  import seaborn as sns
  df.groupby(colname).size().plot(kind='barh', color=sns.palettes.mpl_palette(mpl_palette_name), figsize=(8*figscale, 4.8*figscale))
  plt.gca().spines[['top', 'right',]].set_visible(False)
  return autoviz.MplChart.from_current_mpl_state()

chart = categorical_histogram(df, *['Purpose of the trip'], **{})
chart
# Out:
# <img src="...

# %%
import numpy as np
from google.colab import autoviz

def heatmap(df, x_colname, y_colname, figscale=1, mpl_palette_name='viridis'):
  from matplotlib import pyplot as plt
  import seaborn as sns
  import pandas as pd
  plt.subplots(figsize=(8 * figscale, 8 * figscale))
  df_2dhist = pd.DataFrame({
      x_label: grp[y_colname].value_counts()
      for x_label, grp in df.groupby(x_colname)
  })
  sns.heatmap(df_2dhist, cmap=mpl_palette_name)
  plt.xlabel(x_colname)
  plt.ylabel(y_colname)
  return autoviz.MplChart.from_current_mpl_state()

chart = heatmap(df, *['Gender', 'Marital status'], **{})
chart
# Out:
# <img src="...

# %%
import numpy as np
from google.colab import autoviz

def heatmap(df, x_colname, y_colname, figscale=1, mpl_palette_name='viridis'):
  from matplotlib import pyplot as plt
  import seaborn as sns
  import pandas as pd
  plt.subplots(figsize=(8 * figscale, 8 * figscale))
  df_2dhist = pd.DataFrame({
      x_label: grp[y_colname].value_counts()
      for x_label, grp in df.groupby(x_colname)
  })
  sns.heatmap(df_2dhist, cmap=mpl_palette_name)
  plt.xlabel(x_colname)
  plt.ylabel(y_colname)
  return autoviz.MplChart.from_current_mpl_state()

chart = heatmap(df, *['Main destination', 'Gender'], **{})
chart
# Out:
# <img src="...

# %%
import numpy as np
from google.colab import autoviz

def heatmap(df, x_colname, y_colname, figscale=1, mpl_palette_name='viridis'):
  from matplotlib import pyplot as plt
  import seaborn as sns
  import pandas as pd
  plt.subplots(figsize=(8 * figscale, 8 * figscale))
  df_2dhist = pd.DataFrame({
      x_label: grp[y_colname].value_counts()
      for x_label, grp in df.groupby(x_colname)
  })
  sns.heatmap(df_2dhist, cmap=mpl_palette_name)
  plt.xlabel(x_colname)
  plt.ylabel(y_colname)
  return autoviz.MplChart.from_current_mpl_state()

chart = heatmap(df, *['Type of Stay', 'Main destination'], **{})
chart
# Out:
# <img src="...

# %%
import numpy as np
from google.colab import autoviz

def heatmap(df, x_colname, y_colname, figscale=1, mpl_palette_name='viridis'):
  from matplotlib import pyplot as plt
  import seaborn as sns
  import pandas as pd
  plt.subplots(figsize=(8 * figscale, 8 * figscale))
  df_2dhist = pd.DataFrame({
      x_label: grp[y_colname].value_counts()
      for x_label, grp in df.groupby(x_colname)
  })
  sns.heatmap(df_2dhist, cmap=mpl_palette_name)
  plt.xlabel(x_colname)
  plt.ylabel(y_colname)
  return autoviz.MplChart.from_current_mpl_state()

chart = heatmap(df, *['Mode of travel', 'Type of Stay'], **{})
chart
# Out:
# <img src="...

# %%
import numpy as np
from google.colab import autoviz

def heatmap(df, x_colname, y_colname, figscale=1, mpl_palette_name='viridis'):
  from matplotlib import pyplot as plt
  import seaborn as sns
  import pandas as pd
  plt.subplots(figsize=(8 * figscale, 8 * figscale))
  df_2dhist = pd.DataFrame({
      x_label: grp[y_colname].value_counts()
      for x_label, grp in df.groupby(x_colname)
  })
  sns.heatmap(df_2dhist, cmap=mpl_palette_name)
  plt.xlabel(x_colname)
  plt.ylabel(y_colname)
  return autoviz.MplChart.from_current_mpl_state()

chart = heatmap(df, *['Purpose of the trip', 'Mode of travel'], **{})
chart
# Out:
# <img src="...

# %% [markdown]
# ==================================================================================================================

# %% [markdown]
# **MODEL**

# %% [markdown]
# **Multinomial Logistic Model**

# %%
import pandas as pd
import statsmodels.api as sm

# Load your data into a DataFrame
data = pd.read_csv('/content/data365overnt.csv')
print(data.shape[0])
#renaming the coloumns
data.rename(columns={'b4q4': 'Gender', 'b4q5': 'Age',
                   'b4q6':'Marital status', 'b51q5': 'Purpose of the trip'
                   ,'b51q7' :'Mode of travel','b51q9':'Type of Stay',
                   'b51q14':'Main destination' },inplace=True)
print(data.columns)
# Out:
# 157326
# Index(['HHID', 'b51q1', 'b51q2', 'b51q3', 'b51q4', 'Purpose of the trip',
#        'b51q6', 'Mode of travel', 'b51q8', 'Type of Stay', 'b51q11', 'b51q12',
#        'b51q13', 'Main destination', 'b51q15', 'INDID', 'b4q1', 'Gender',
#        'Age', 'Marital status', 'b4q7', 'b4q8', 'HHType', 'b3q5', 'b3q6',
#        'b3q7', 'TripID', 'b61q1', 'b61q2', 'b61q40', 'b61q50', 'b61q60',
#        'b61q700', 'b61q851', 'b61q852', 'b61q853', 'b61q850', 'b61q80',
#        'b61q10', 'b61q11', 'b61q12'],
#       dtype='object')
# <ipython-input-25-1b30424d18eb>:5: DtypeWarning: Columns (4,7,9,10,12,13,14,25,40) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('/content/data365overnt.csv')

# %%
# Map values for the outcome variable (gender)
data['Gender'] = data['Gender'].map({1: 'Male', 2: 'Female', 3: 'Third Gender'})

# Map values for the dependent variables


data['Marital status'] = data['Marital status'].map({1: 'never married', 2:'currently married',3 : 'widowed', 4 : 'divorced'})
data['Type of Stay'] = data['Type of Stay'].map({'1': 'Type of Stay_hotel', "3":'Type of Stay_dharmashala',
                                             5 : 'Type of Stay_friends/relatives','4':'Type of Stay_RentedHouse','2':'Type of Stay_guestHouse', 9:'Type of Stay_others','9':'Type of Stay_others'})
data['Mode of travel'] = data['Mode of travel'].map({2: 'Mode of travel_bus', 3:'Mode of travel_train',6 : 'Mode of travel_own',
                                                 8: 'Mode of travel_motorizedVehicle',10: 'Mode of travel_Non_motorizedVehicle',"1":'Mode of travel_onFoot',4:'Mode of travel_ship/boat',5:'Mode of travel_air',"7":'Mode of travel_ownNonMotorized',"19":'Mode of travel_others'})
data['Purpose of the trip'] = data['Purpose of the trip'].map({2: 'Purpose of the trip_holidaying', 6:'Purpose of the trip_health/medical',7 : 'Purpose of the trip_shopping',1: 'Purpose of the trip_business',3: 'Purpose of the trip_social',4: 'Purpose of the trip_pilgrimage&religious',5: 'Purpose of the trip_education/training',9: 'Purpose of the trip_others'})
data['Main destination'] = data['Main destination'].map({'1': 'destination within the district', '2':'destination outside the district but within the state','3' : 'destination outside the district but within the state','4':	"final part of departure in Indian Territory for International trip"})

# %%
# Define your predictor variables, including the newly mapped ones
predictor_variables = ['Gender', 'Marital status', 'Type of Stay', 'Mode of travel',
                       'Purpose of the trip', 'Main destination', 'Age']

# Create dummy variables for the categorical predictor variables
data = pd.get_dummies(data, columns=['Gender', 'Marital status', 'Type of Stay', 'Mode of travel',
                                     'Purpose of the trip', 'Main destination'], drop_first=True)

# %%
# Check the column names to verify the corrected name
print(data.columns)

# Access the 'Gender' column
y = data['Gender_Male']
# Out:
# Index(['HHID', 'b51q1', 'b51q2', 'b51q3', 'b51q4', 'b51q6', 'b51q8', 'b51q11',
#        'b51q12', 'b51q13', 'b51q15', 'INDID', 'b4q1', 'Age', 'b4q7', 'b4q8',
#        'HHType', 'b3q5', 'b3q6', 'b3q7', 'TripID', 'b61q1', 'b61q2', 'b61q40',
#        'b61q50', 'b61q60', 'b61q700', 'b61q851', 'b61q852', 'b61q853',
#        'b61q850', 'b61q80', 'b61q10', 'b61q11', 'b61q12', 'Gender_Male',
#        'Gender_Third Gender', 'Marital status_divorced',
#        'Marital status_never married', 'Marital status_widowed',
#        'Type of Stay_Type of Stay_dharmashala',
#        'Type of Stay_Type of Stay_friends/relatives',
#        'Type of Stay_Type of Stay_guestHouse',
#        'Type of Stay_Type of Stay_hotel', 'Type of Stay_Type of Stay_others',
#        'Mode of travel_Mode of travel_air',
#        'Mode of travel_Mode of travel_bus',
#        'Mode of travel_Mode of travel_motorizedVehicle',
#        'Mode of travel_Mode of travel_onFoot',
#        'Mode of travel_Mode of travel_others',
# ...

# %%
predictor_variables = ['Marital status_divorced',
       'Marital status_never married', 'Marital status_widowed',
       'Type of Stay_Type of Stay_dharmashala',
       'Type of Stay_Type of Stay_friends/relatives',
       'Type of Stay_Type of Stay_guestHouse',
       'Type of Stay_Type of Stay_hotel', 'Type of Stay_Type of Stay_others',
       'Mode of travel_Mode of travel_air',
       'Mode of travel_Mode of travel_bus',
       'Mode of travel_Mode of travel_motorizedVehicle',
       'Mode of travel_Mode of travel_others',
       'Mode of travel_Mode of travel_own',
       'Mode of travel_Mode of travel_ownNonMotorized',
       'Mode of travel_Mode of travel_ship/boat',
       'Mode of travel_Mode of travel_train',
       'Purpose of the trip_Purpose of the trip_education/training',
       'Purpose of the trip_Purpose of the trip_health/medical',
       'Purpose of the trip_Purpose of the trip_holidaying',
       'Purpose of the trip_Purpose of the trip_others',
       'Purpose of the trip_Purpose of the trip_pilgrimage&religious',
       'Purpose of the trip_Purpose of the trip_shopping',
       'Purpose of the trip_Purpose of the trip_social',
       'Main destination_destination within the district', 'Age']

# %%
# Access the 'Gender' column
y = data['Gender_Male']
# Add an intercept (constant)
X = sm.add_constant(data[predictor_variables])

# %%
# Fit a Multinomial Logistic Regression model
mnl_model = sm.MNLogit(y, X)

# Fit the model
mnl_results = mnl_model.fit()

# Print the model summary
print(mnl_results.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.664383
#          Iterations 5
#                           MNLogit Regression Results
# ...
# Dep. Variable:            Gender_Male   No. Observations:               157326
# Model:                        MNLogit   Df Residuals:                   157300
# Method:                           MLE   Df Model:                           25
# Date:                Mon, 23 Oct 2023   Pseudo R-squ.:                 0.03994
# Time:                        03:27:21   Log-Likelihood:            -1.0452e+05
# converged:                       True   LL-Null:                   -1.0887e+05
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ...
#                                                Gender_Male=1       coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------------------------
# ...
